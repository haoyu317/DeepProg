# %%
import pandas as pd

# %%
rna_df = pd.read_csv("HCC/Part2_BasicDataProcessingResult/LIHC__geneExp.txt",sep = '\t')

# %%
rna_df = rna_df.T

# %%
len(rna_df)
# Out:
# 426

# %%
rna_df.head(4)
# Out:
#                                   0          1        2        3       4      \
# GeneSymbol                            ?          ?        ?        ?       ?
# EntrezID                      100133144  100134869    10357    10431  136542
# TCGA-OR-A5J1-01A-11R-A29S-07     3.2661     3.9385  149.135   2034.1       0
# TCGA-OR-A5J2-01A-11R-A29S-07     2.6815     8.9948  81.0777  1304.93       0
#
#                                 5       6       7       8        9      ...  \
# GeneSymbol                          ?       ?       ?       ?        ?  ...
# EntrezID                       155060   26823  280660  317712   340602  ...
# TCGA-OR-A5J1-01A-11R-A29S-07  274.255  1.4409       0       0  17.7714  ...
# TCGA-OR-A5J2-01A-11R-A29S-07  199.302       0       0       0   0.4026  ...
#
#                                 20520    20521    20522    20523    20524  \
# GeneSymbol                     ZWILCH    ZWINT     ZXDA     ZXDB     ZXDC
# ...

# %%
rna_df.reset_index(inplace = True)
rna_df.columns = rna_df.iloc[0]
rna_df = rna_df[2:]
rna_df = rna_df.rename(columns = {"GeneSymbol":"Samples"})

# %%
rna_df.to_csv("ACC/rna.tsv",index = False,sep = '\t')

# %%
mrna_df =  pd.read_csv("HCC/Part2_BasicDataProcessingResult/LIHC__miRNAExp__RPM.txt",sep = '\t')
mrna_df = mrna_df.T
mrna_df.reset_index(inplace = True)

# %%
len(mrna_df)
# Out:
# 422

# %%
mrna_df.head(4)
# Out:
#                           index             0             1             2  \
# 0                    GeneSymbol  hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3
# 1  TCGA-OR-A5J1-01A-11R-A29W-13       13476.1       26756.7       13703.3
# 2  TCGA-OR-A5J2-01A-11R-A29W-13       4440.86       8799.33       4601.52
# 3  TCGA-OR-A5J3-01A-11R-A29W-13       7041.98       14003.6       7064.07
#
#             3           4           5           6             7             8  \
# 0  hsa-let-7b  hsa-let-7c  hsa-let-7d  hsa-let-7e  hsa-let-7f-1  hsa-let-7f-2
# 1     15202.9     1963.95     1722.24     2680.78       46.1503       16790.9
# 2     11209.7     1654.24     1256.68     1373.86       14.0728       2828.93
# 3     10654.2     742.691     398.813     3171.34       46.9191       13291.6
#
#    ...           1860           1861         1862         1863         1864  \
# 0  ...  hsa-mir-941-3  hsa-mir-941-4  hsa-mir-942  hsa-mir-943  hsa-mir-944
# ...

# %%
mrna_df.columns = mrna_df.iloc[0]

# %%
mrna_df.head(4)
# Out:
# 0                    GeneSymbol  hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3  \
# 0                    GeneSymbol  hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3
# 1  TCGA-OR-A5J1-01A-11R-A29W-13       13476.1       26756.7       13703.3
# 2  TCGA-OR-A5J2-01A-11R-A29W-13       4440.86       8799.33       4601.52
# 3  TCGA-OR-A5J3-01A-11R-A29W-13       7041.98       14003.6       7064.07
#
# 0  hsa-let-7b  hsa-let-7c  hsa-let-7d  hsa-let-7e  hsa-let-7f-1  hsa-let-7f-2  \
# 0  hsa-let-7b  hsa-let-7c  hsa-let-7d  hsa-let-7e  hsa-let-7f-1  hsa-let-7f-2
# 1     15202.9     1963.95     1722.24     2680.78       46.1503       16790.9
# 2     11209.7     1654.24     1256.68     1373.86       14.0728       2828.93
# 3     10654.2     742.691     398.813     3171.34       46.9191       13291.6
#
# 0  ...  hsa-mir-941-3  hsa-mir-941-4  hsa-mir-942  hsa-mir-943  hsa-mir-944  \
# 0  ...  hsa-mir-941-3  hsa-mir-941-4  hsa-mir-942  hsa-mir-943  hsa-mir-944
# ...

# %%
mrna_df = mrna_df[1:]
mrna_df = mrna_df.rename(columns = {"GeneSymbol":"Samples"})

# %%
mrna_df.head(4)
# Out:
# 0                       Samples hsa-let-7a-1 hsa-let-7a-2 hsa-let-7a-3  \
# 1  TCGA-OR-A5J1-01A-11R-A29W-13      13476.1      26756.7      13703.3
# 2  TCGA-OR-A5J2-01A-11R-A29W-13      4440.86      8799.33      4601.52
# 3  TCGA-OR-A5J3-01A-11R-A29W-13      7041.98      14003.6      7064.07
# 4  TCGA-OR-A5J4-01A-11R-A29W-13      11043.4      22197.7      11170.2
#
# 0 hsa-let-7b hsa-let-7c hsa-let-7d hsa-let-7e hsa-let-7f-1 hsa-let-7f-2  ...  \
# 1    15202.9    1963.95    1722.24    2680.78      46.1503      16790.9  ...
# 2    11209.7    1654.24    1256.68    1373.86      14.0728      2828.93  ...
# 3    10654.2    742.691    398.813    3171.34      46.9191      13291.6  ...
# 4    14483.1    3901.53    1904.87    2856.99      84.7534      19160.7  ...
#
# 0 hsa-mir-941-3 hsa-mir-941-4 hsa-mir-942 hsa-mir-943 hsa-mir-944 hsa-mir-95  \
# 1             0             0     1.76821    0.176821           0    5.83509
# ...

# %%
mrna_df.to_csv("ACC/mirna.tsv",index = False,sep = '\t')

# %%
len(mrna_df)
# Out:
# 79

# %%
meth_df =  pd.read_csv("ACC/Part3_AdvancedDataProcessingResult/ACC__methylation_450__TSS200-TSS1500__Both.txt",sep = '\t')
meth_df = meth_df.T
meth_df.reset_index(inplace = True)

# %%
meth_df.columns = meth_df.iloc[0]
meth_df = meth_df[2:]
meth_df = meth_df.rename(columns = {"GeneSymbol":"Samples"})

# %%
meth_df.head(4)
# Out:
# 0                       Samples     WASH5P     OR4F5   MIR1977  LOC643837  \
# 2  TCGA-OR-A5J1-01A-11D-A29J-05  0.0975656  0.710663  0.106165  0.0204862
# 3  TCGA-OR-A5J2-01A-11D-A29J-05  0.0773728  0.234449  0.119204  0.0194322
# 4  TCGA-OR-A5J3-01A-11D-A29J-05   0.062482  0.419968  0.140401  0.0196624
# 5  TCGA-OR-A5J4-01A-11D-A29J-05   0.101781  0.293361  0.106486  0.0268422
#
# 0  LINC00115    FAM41C  FLJ39609     SAMD11    KLHL17  ...     H2AB1  \
# 2  0.0204862  0.785968  0.786421  0.0655286  0.525882  ...  0.944692
# 3  0.0194322   0.38298  0.320797  0.0573512  0.431292  ...  0.953963
# 4  0.0196624  0.630712  0.490206   0.060129  0.461492  ...   0.97084
# 5  0.0268422  0.453072  0.662908  0.0623472  0.495345  ...  0.962939
#
# 0     H2AB3     FUNDC2      BRCC3      MTCP1       CMC4       VBP1    RAB39B  \
# 2  0.944692  0.0842993  0.0433652  0.0433652  0.0433652  0.0625957  0.108488
# 3  0.953963    0.58213   0.442495   0.442495   0.442495   0.288474  0.501144
# ...

# %%
meth_df.to_csv("ACC/meth.tsv",index = False,sep = '\t')

# %%
copynumber_df =  pd.read_csv("HCC/Part2_BasicDataProcessingResult/LIHC__copyNumber.txt",sep = '\t')

# %%
copynumber_df.head(5)
# Out:
#   GeneSymbol Chromosome Strand  TCGA-2V-A95S-01A-11D-A36W-01  \
# 0    DDX11L1       CHR1      +                           NaN
# 1     WASH7P       CHR1      -                           NaN
# 2    FAM138A       CHR1      -                           NaN
# 3      OR4F5       CHR1      +                       -0.0577
# 4  LOC729737       CHR1      -                       -0.0577
#
#    TCGA-2V-A95S-10D-01D-A36Z-01  TCGA-2Y-A9GS-01A-12D-A381-01  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                        0.0539                       -0.3162
# 4                        0.0539                       -0.3162
#
#    TCGA-2Y-A9GS-10A-01D-A384-01  TCGA-2Y-A9GT-01A-11D-A381-01  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# ...

# %%
copynumber_df = copynumber_df.T
copynumber_df.reset_index(inplace = True)

# %%
copynumber_df.head(10)
# Out:
#                           index        0       1        2       3          4  \
# 0                    GeneSymbol  DDX11L1  WASH7P  FAM138A   OR4F5  LOC729737
# 1                    Chromosome     CHR1    CHR1     CHR1    CHR1       CHR1
# 2                        Strand        +       -        -       +          -
# 3  TCGA-2V-A95S-01A-11D-A36W-01      NaN     NaN      NaN -0.0577    -0.0577
# 4  TCGA-2V-A95S-10D-01D-A36Z-01      NaN     NaN      NaN  0.0539     0.0539
# 5  TCGA-2Y-A9GS-01A-12D-A381-01      NaN     NaN      NaN -0.3162    -0.3162
# 6  TCGA-2Y-A9GS-10A-01D-A384-01      NaN     NaN      NaN -0.0244    -0.0244
# 7  TCGA-2Y-A9GT-01A-11D-A381-01      NaN     NaN      NaN -0.0128    -0.0128
# 8  TCGA-2Y-A9GT-10A-01D-A384-01      NaN     NaN      NaN -0.3185    -0.3185
# 9  TCGA-2Y-A9GU-01A-11D-A381-01      NaN     NaN      NaN -0.0434    -0.0434
#
#               5       6       7             8  ...   24906   24907    24908  \
# ...

# %%
copynumber_df.columns = copynumber_df.iloc[0]

# %%
copynumber_df.head(10)
# Out:
# 0                    GeneSymbol  DDX11L1  WASH7P  FAM138A   OR4F5  LOC729737  \
# 0                    GeneSymbol  DDX11L1  WASH7P  FAM138A   OR4F5  LOC729737
# 1                    Chromosome     CHR1    CHR1     CHR1    CHR1       CHR1
# 2                        Strand        +       -        -       +          -
# 3  TCGA-2V-A95S-01A-11D-A36W-01      NaN     NaN      NaN -0.0577    -0.0577
# 4  TCGA-2V-A95S-10D-01D-A36Z-01      NaN     NaN      NaN  0.0539     0.0539
# 5  TCGA-2Y-A9GS-01A-12D-A381-01      NaN     NaN      NaN -0.3162    -0.3162
# 6  TCGA-2Y-A9GS-10A-01D-A384-01      NaN     NaN      NaN -0.0244    -0.0244
# 7  TCGA-2Y-A9GT-01A-11D-A381-01      NaN     NaN      NaN -0.0128    -0.0128
# 8  TCGA-2Y-A9GT-10A-01D-A384-01      NaN     NaN      NaN -0.3185    -0.3185
# 9  TCGA-2Y-A9GU-01A-11D-A381-01      NaN     NaN      NaN -0.0434    -0.0434
#
# 0  LOC100132287  OR4F29  OR4F16  LOC100133331  ...  TTTY4B  TTTY4C  TTTY17C  \
# ...

# %%
copynumber_df = copynumber_df[3:]
copynumber_df = copynumber_df.rename(columns = {"GeneSymbol":"Samples"})

# %%
copynumber_df.dropna(axis = 1, inplace = True)

# %%
copynumber_df.head(10)
# Out:
# 0                        Samples LOC100288069 LINC00115 LOC643837  FAM41C  \
# 3   TCGA-2V-A95S-01A-11D-A36W-01      -0.0577   -0.0577   -0.0577 -0.0577
# 4   TCGA-2V-A95S-10D-01D-A36Z-01       0.0539    0.0539    0.0539  0.0539
# 5   TCGA-2Y-A9GS-01A-12D-A381-01       0.1354    0.1354    0.1354  0.1354
# 6   TCGA-2Y-A9GS-10A-01D-A384-01      -0.0244   -0.0244   -0.0244 -0.0244
# 7   TCGA-2Y-A9GT-01A-11D-A381-01      -0.0128   -0.0128   -0.0128 -0.0128
# 8   TCGA-2Y-A9GT-10A-01D-A384-01      -0.3185     0.376     0.376   0.376
# 9   TCGA-2Y-A9GU-01A-11D-A381-01      -0.0434   -0.0434   -0.0434 -0.0434
# 10  TCGA-2Y-A9GV-01A-11D-A381-01      -0.0462   -0.0462   -0.0462 -0.0462
# 11  TCGA-2Y-A9GV-10A-01D-A384-01       -0.125    -0.125    -0.125  -0.125
# 12  TCGA-2Y-A9GW-01A-11D-A381-01      -0.1075   -0.1075   -0.1075 -0.1075
#
# 0   SAMD11   NOC2L PLEKHN1   PERM1   ISG15  ... GOLGA2P3Y    DAZ3   BPY2C  \
# 3  -0.0577 -0.0577 -0.0577 -0.0577 -0.0577  ...   -0.3997 -0.3997 -0.3997
# ...

# %%
copynumber_df.to_csv("HCC/copynumber.tsv",index = False,sep = '\t')
